# %%
from nba_py import player
from nba_py.player import get_player
from nba_py import constants
from nba_py import team
from nba_py import game
from nba_py.constants import TEAMS

import pickle
import re
import time
import json
import pprint as pp
import sys
import pandas as pd

from time import time,sleep

# %%
def scrape_matchups(): 
    
    df = pd.read_pickle('./player_game_table.pkl')
    seasons = ["2017-2018", "2016-2017", "2015-2016"]
    #print(df.head(1))
    game_ids = df.loc[(df.player_id == "2544") & (df.season.isin(seasons))]
    player_ids = set([])
    count = 0
    for idx, row in game_ids.iterrows():
        if not count%10:
            print(count, " out of ", game_ids.shape)
        count += 1
        
        all_games = df.loc[(df.game_id == row.game_id) & (df.team_id != row.team_id)]
        #print(all_games)
        for idx, game_row in all_games.iterrows():
            player_ids.add(game_row.player_id)

    print(len(player_ids))
    print(player_ids)
    
    return player_ids

# %%
player_ids = scrape_matchups()
# Out:
# 0  out of  (232, 33)
# 10  out of  (232, 33)
# 20  out of  (232, 33)
# 30  out of  (232, 33)
# 40  out of  (232, 33)
# 50  out of  (232, 33)
# 60  out of  (232, 33)
# 70  out of  (232, 33)
# 80  out of  (232, 33)
# 90  out of  (232, 33)
# 100  out of  (232, 33)
# 110  out of  (232, 33)
# 120  out of  (232, 33)
# 130  out of  (232, 33)
# 140  out of  (232, 33)
# 150  out of  (232, 33)
# 160  out of  (232, 33)
# 170  out of  (232, 33)
# 180  out of  (232, 33)
# 190  out of  (232, 33)
# 200  out of  (232, 33)
# 210  out of  (232, 33)
# 220  out of  (232, 33)
# 230  out of  (232, 33)
# 559
# {'1627851', '203956', '1626273', '200765', '1627770', '201960', '201581', '1627785', '201978', '2734', '203897', '1626242', '201601', '203944', '203382', '1626245', '2561', '1627863', '203925', '1938', '202362', '201943', '204001', '1628397', '202692', '1627817', '203901', '204060', '2210', '1628467', '203096', '1627815', '1626162', '1626154', '201933', '203919', '203477', '202688', '101108', '1626192', '203518', '203994', '203961', '2749', '2581', '1627849', '1626166', '201976', '203933', '1626168', '1627767', '201609', '203497', '200779', '203530', '201956', '101139', '2772', '202738', '1628373', '203503', '202702', '1626202', '203515', '202331', '202338', '200752', '202339', '1626159', '203516', '202344', '202328', '1627747', '204020', '2736', '201202', '1627740', '1627883', '202337', '1626143', '203141', '201163', '203100', '202683', '201628', '202779', '1626163', '203079', '1628372', '203943', '202390', '1628464', '1627835', '1628400', '203490', '203930', '1628436', '203939', '1628381', '101109', '202696', '201593', '1626167', '201575', '203085', '1626144', '201166', '2225', '101114', '202713', '202334', '202327', '203464', '1628388', '2754', '1628416', '202349', '1627736', '1626203', '1628374', '200771', '201961', '203210', '201578', '2207', '203148', '203114', '201162', '203546', '203932', '1717', '1626153', '200746', '201954', '203898', '203120', '1626175', '2564', '1627781', '1627774', '202357', '1628393', '203935', '1628367', '203962', '203086', '1626170', '1626780', '1628369', '203101', '1626147', '203484', '202341', '1628415', '1627788', '1626209', '1626204', '203485', '1627758', '201587', '2200', '202708', '1628380', '1626173', '1627741', '200757', '202391', '203948', '201627', '1626176', '203953', '1626172', '2446', '203996', '202700', '203457', '101123', '202087', '204456', '1626179', '202326', '201596', '1628439', '1627875', '1626157', '1627832', '1628386', '2034', '2744', '2733', '203903', '201171', '201941', '200782', '101107', '2594', '203458', '2756', '203200', '204038', '1628390', '1627775', '1626161', '201980', '203552', '1628370', '1626196', '202347', '1495', '201950', '1627748', '203469', '201589', '1626171', '203093', '1626181', '1627756', '200811', '2585', '202322', '202693', '1626177', '203906', '1627848', '203521', '1627755', '201942', '1628404', '1627846', '203496', '977', '203476', '203613', '1627759', '203952', '1626253', '201150', '203081', '2405', '203112', '201952', '203110', '1897', '202083', '203486', '201973', '101135', '2399', '1626178', '201188', '2548', '201600', '203121', '203482', '201951', '2216', '203082', '201586', '1626164', '201168', '201142', '201196', '202694', '203526', '201580', '1627098', '1628021', '101133', '201573', '202704', '201564', '203088', '2406', '203468', '203924', '1718', '203099', '200755', '203493', '1627816', '201959', '203991', '203585', '1628382', '204014', '1626191', '1627868', '204067', '202682', '2546', '203508', '203462', '201977', '1627737', '1628422', '201228', '203481', '1628463', '2550', '202325', '1628469', '1628462', '202687', '1627738', '203459', '202335', '203921', '1627812', '1627827', '1627750', '203078', '203124', '1626185', '202689', '2037', '201939', '203992', '203115', '203080', '2419', '1627783', '203471', '2731', '1626199', '101181', '203461', '1627786', '202720', '203084', '201585', '202703', '1626151', '202323', '1626169', '2743', '201584', '203922', '203999', '202734', '1713', '203798', '202397', '202709', '203900', '200745', '203909', '203094', '203967', '1626214', '1626155', '201566', '1891', '201177', '1627761', '203501', '203912', '101161', '203914', '203512', '1628365', '203123', '1627855', '203934', '201599', '1627884', '1627735', '203920', '1626150', '201579', '201603', '1628371', '2199', '1626156', '203076', '2571', '200797', '1626246', '201144', '202329', '1627854', '201967', '203893', '203940', '201160', '2403', '2588', '203143', '202699', '1628378', '203083', '200768', '203156', '201158', '1627362', '101187', '202389', '20395 ...

# %%
def not_really_scraping(player_ids):
    t0 = time()
    api_seasons = ["2017-18", "2016-17", "2015-16"]
    headers = ['player_id', 'min', 'fgm', 'fga', 'fg3m', 
    'fg3a', 'ftm', 'fta', 'oreb', 'dreb', 'reb', 'ast', 'tov','stl', 'blk', 'pts', 'season', 'player_vs_id', 'fp']
    not_input = {}
    for header in headers:
        not_input[header] = []
    count = 0
    responses = []
    
    for player_id in player_ids:
        count += 1
        
        for season in api_seasons:
            sleep(0.1)
            response = player.PlayerVsPlayer(2544,player_id, season=season).json
            responses.append(response)
            for header in headers:
                if header.upper() in response['resultSets'][0]['headers']:
                    idx = response['resultSets'][0]['headers'].index(header.upper())
                    not_input[header].append(str(response['resultSets'][0]['rowSet'][0][idx]))
                
            #add FP
            not_input['season'].append(season)
            not_input['player_vs_id'].append(player_id)
            not_input['fp'].append('meme')
            
        if not(count%10):
            print(count, " out of ", len(player_ids))
            print('Just completed: ' + str(count) + ' with an ETC of ' +  str( ((time() - t0)/(count)) * (len(player_ids) - (count) )))
            #assert(1==0)
    #pp.pprint(response['resultSets'][0])
    df = pd.DataFrame(data=not_input)
    df.to_pickle('./player_vs_table.pkl')
    pickle.dump(responses,open('./raw_player_matchup_responses.pkl','wb'))

# %%
not_really_scraping(player_ids)
# Out:
# 10  out of  559
# Just completed: 10 with an ETC of 434.53258166313174
# 20  out of  559
# Just completed: 20 with an ETC of 1711.760711491108
# 30  out of  559
# Just completed: 30 with an ETC of 2043.88157684803
# 40  out of  559
# Just completed: 40 with an ETC of 2188.2394092142586
# 50  out of  559
# Just completed: 50 with an ETC of 2292.679180035591
# 60  out of  559
# Just completed: 60 with an ETC of 2316.332813707987
# 70  out of  559
# Just completed: 70 with an ETC of 2326.8488064459393
# 80  out of  559
# Just completed: 80 with an ETC of 2309.4346738219265
# 90  out of  559
# Just completed: 90 with an ETC of 2288.963355414073
# 100  out of  559
# Just completed: 100 with an ETC of 2250.0872183990477
# 110  out of  559
# Just completed: 110 with an ETC of 2237.6527712605216
# 120  out of  559
# Just completed: 120 with an ETC of 2181.4951894223686
# 130  out of  559
# Just completed: 130 with an ETC of 2155.107898306847
# 140  out of  559
# Just completed: 140 with an ETC of 2115.5166729739735
# 150  out of  559
# Just completed: 150 with an ETC of 2070.7836586348217
# 160  out of  559
# Just completed: 160 with an ETC of 2027.5423766925933
# 170  out of  559
# Just completed: 170 with an ETC of 1982.8130202587915
# 180  out of  559
# Just completed: 180 with an ETC of 1948.560707490974
# 190  out of  559
# Just completed: 190 with an ETC of 1900.1352392849167
# 200  out of  559
# Just completed: 200 with an ETC of 1854.1491834783553
# 210  out of  559
# Just completed: 210 with an ETC of 1806.703511867069
# 220  out of  559
# Just completed: 220 with an ETC of 1757.2237527868965
# 230  out of  559
# Just completed: 230 with an ETC of 1708.2001051560692
# 240  out of  559
# Just completed: 240 with an ETC of 1661.811025310556
# 250  out of  559
# Just completed: 250 with an ETC of 1616.0356791744234
# 260  out of  559
# Just completed: 260 with an ETC of 1565.5569635629654
# 270  out of  559
# Just completed: 270 with an ETC of 1516.2569969459817
# 280  out of  559
# Just completed: 280 with an ETC of 1461.9802212825844
# 290  out of  559
# Just completed: 290 with an ETC of 1410.7339520988794
# 300  out of  559
# Just completed: 300 with an ETC of 1356.1585342884064
# 310  out of  559
# Just completed: 310 with an ETC of 1301.9538073978117
# 320  out of  559
# Just completed: 320 with an ETC of 1250.7188301250337
# 330  out of  559
# Just completed: 330 with an ETC of 1200.1586103179238
# 340  out of  559
# Just completed: 340 with an ETC of 1152.0825846875414
# 350  out of  559
# Just completed: 350 with an ETC of 1098.788223612649
# 360  out of  559
# Just completed: 360 with an ETC of 1049.8588455557822
# 370  out of  559
# Just completed: 370 with an ETC of 995.150447829994
# 380  out of  559
# Just completed: 380 with an ETC of 942.1859883597023
# 390  out of  559
# Just completed: 390 with an ETC of 888.9118937889735
# 400  out of  559
# Just completed: 400 with an ETC of 836.1187188613414
# 410  out of  559
# Just completed: 410 with an ETC of 783.4298007482436
# 420  out of  559
# Just completed: 420 with an ETC of 731.1930404833385
# 430  out of  559
# Just completed: 430 with an ETC of 679.0701734304429
# 440  out of  559
# Just completed: 440 with an ETC of 626.7627760941332
# 450  out of  559
# Just completed: 450 with an ETC of 574.9752356211345
# 460  out of  559
# Just completed: 460 with an ETC of 522.6835344718851
# 470  out of  559
# Just completed: 470 with an ETC of 469.75749571475575
# 480  out of  559
# Just completed: 480 with an ETC of 417.3641223882635
# 490  out of  559
# Just completed: 490 with an ETC of 364.53876205561113
# 500  out of  559
# Just completed: 500 with an ETC of 311.8360828828812
# 510  out of  559
# Just completed: 510 with an ETC of 259.27587184391774
# 520  out of  559
# Just completed: 520 with an ETC of 206.3454738378525
# 530  out of  559
# Just completed: 530 with an ETC of 153.37538893267794
# 540  out of  559
# Just completed: 540 with an ETC of 100.43574415975148
# 550  out of  559
# Just completed: 550 with an ETC of 47.534346548860725
